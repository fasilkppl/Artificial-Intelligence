# %%
#Histogram
import pandas as pd
df_score = pd.read_excel("histograms.xlsx")
df_score.head()
# Out:
#        Name  Exam_Score
# 0     Aarav          45
# 1   Michael          71
# 2     Bilal          59
# 3  Priyanka          92
# 4    Sophia           0

# %%
import seaborn as sns
sns.histplot(df_score['Exam_Score'],kde=True)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Count'>

# %%
#another method same results
sns.histplot(data = df_score, x='Exam_Score', kde=True)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Count'>

# %%
#scatter plot
df_scatter = pd.read_excel("scatter_plot.xlsx")
df_scatter.head()
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34

# %%
#in scatter polot we must sepcifiy x and y axis
sns.scatterplot(data=df_scatter, x= 'area_square_ft', y='price')
# Out:
# <Axes: xlabel='area_square_ft', ylabel='price'>
