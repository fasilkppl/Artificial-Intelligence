# %%
# Stemming in NLTK

# %%
from nltk.stem import PorterStemmer
# Create an instance of the PorterStemmer, here PorterStemmer is the class and stemmer is the object that we created.
stemmer = PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
    print(word, "|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet

# %%
# Lemmatization in Spacy
# spacy does not support stemming, only lemmatization.

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("Mando talked for 3 hours although talking isn't his thing")
doc = nlp("eating eats eat ate adjustable rafting ability meeting better")
for token in doc:
    print(token, " | ", token.lemma_) # print the word and its lemma
# Out:
# eating  |  eat
# eats  |  eat
# eat  |  eat
# ate  |  eat
# adjustable  |  adjustable
# rafting  |  raft
# ability  |  ability
# meeting  |  meet
# better  |  well

# %%
# Customizing lemmatizer

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Get the attribute ruler from the pipeline
ar = nlp.get_pipe('attribute_ruler')

# add custom lemmatization rules, here we are telling spacy to lemmatize "Bro" and "Brah" to "Brother"
ar.add([[{"TEXT":"Bro"}],[{"TEXT":"Brah"}]],{"LEMMA":"Brother"}) 
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")
for token in doc:
    print(token.text, "|", token.lemma_)
# Out:
# Bro | Brother
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brother
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust

# %%
doc[0]
# Out:
# Bro

# %%
doc[0].lemma_
# Out:
# 'Brother'

# %%
doc[6]
# Out:
# Brah

# %%
doc[6].lemma_
# Out:
# 'Brother'
